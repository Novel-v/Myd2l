# %%
import torch
import torchvision
from torch import nn
from d2l import torch as d2l

# %%
def nin_block(in_channels, out_channels, kernel_size, padding, stride):
    return nn.Sequential(
        nn.Conv2d(in_channels,out_channels,kernel_size,stride,padding),
        nn.ReLU(),
        nn.Conv2d(out_channels,out_channels,kernel_size=1), nn.ReLU(),
        nn.Conv2d(out_channels,out_channels,kernel_size=1), nn.ReLU()
    )

# %%
net = nn.Sequential(
    nin_block(1,96,kernel_size=11,stride=4,padding=0),
    nn.MaxPool2d(3,stride=2),
    nin_block(96,256,kernel_size=5,stride=1,padding=2),
    nn.MaxPool2d(3,stride=2),
    nin_block(256,384,kernel_size=3,stride=1,padding=1),
    nn.MaxPool2d(3,stride=2),
    nn.Dropout(0.5),
    nin_block(384,10,kernel_size=3,stride=1,padding=1),
    nn.AdaptiveAvgPool2d((1,1)),
    nn.Flatten()
)

# %%
X = torch.randn(1,1,224,224)
for layer in net:
    X = layer(X)
    print(layer.__class__.__name__,'output shape:\t',X.shape)
# Out:
# Sequential output shape:	 torch.Size([1, 96, 54, 54])
# MaxPool2d output shape:	 torch.Size([1, 96, 26, 26])
# Sequential output shape:	 torch.Size([1, 256, 26, 26])
# MaxPool2d output shape:	 torch.Size([1, 256, 12, 12])
# Sequential output shape:	 torch.Size([1, 384, 12, 12])
# MaxPool2d output shape:	 torch.Size([1, 384, 5, 5])
# Dropout output shape:	 torch.Size([1, 384, 5, 5])
# Sequential output shape:	 torch.Size([1, 10, 5, 5])
# AdaptiveAvgPool2d output shape:	 torch.Size([1, 10, 1, 1])
# Flatten output shape:	 torch.Size([1, 10])

# %%
lr, num_epochs, batch_size = 0.1, 4, 128
train_iter, test_iter = d2l.load_data_fashion_mnist(batch_size, resize=224)
d2l.train_ch6(net, train_iter, test_iter, num_epochs, lr, d2l.try_gpu())
# Out:
# loss 1.879, train acc 0.284, test acc 0.150
# 2295.7 examples/sec on cuda:0

# %%
# !nvidia-smi
# Out:
# Wed Apr 30 16:10:00 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 566.14                 Driver Version: 566.14         CUDA Version: 12.7     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 4070 ...  WDDM  |   00000000:01:00.0  On |                  N/A |
# | 44%   38C    P5             20W /  220W |    8376MiB /  12282MiB |     39%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A       816      C   ...tWare\Anaconda3\envs\sup\python.exe      N/A      |
# |    0   N/A  N/A      1052    C+G   D:\SoftWare\ToDesk\ToDesk.exe               N/A      |
# |    0   N/A  N/A      1176    C+G   ...\PyCharm 2024.3.2\bin\pycharm64.exe      N/A      |
# |    0   N/A  N/A      2176    C+G   ...on\135.0.3179.98\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A      4400    C+G   ...on\135.0.3179.98\msedgewebview2.exe      N/A      |
# |    0   N/A  N/A      5312    C+G   ...siveControlPanel\SystemSettings.exe      N/A      |
# |    0   N/A  N/A      5592    C+G   ...nt.CBS_cw5n1h2txyewy\SearchHost.exe      N/A      |
# |    0   N/A  N/A      8524    C+G   ...oogle\Chrome\Application\chrome.exe      N/A      |
# |    0   N/A  N/A      9764    C+G   C:\Windows\System32\ShellHost.exe           N/A      |
# |    0   N/A  N/A      9912    C+G   ...5n1h2txyewy\ShellExperienceHost.exe      N/A      |
# |    0   N/A  N/A     10500    C+G   ...2txyewy\StartMenuExperienceHost.exe      N/A      |
# |    0   N/A  N/A     10688    C+G   ...s\System32\ApplicationFrameHost.exe      N/A      |
# |    0   N/A  N/A     13656    C+G   ...crosoft\Edge\Application\msedge.exe      N/A      |
# |    0   N/A  N/A     15544    C+G   C:\Windows\explorer.exe                     N/A      |
# |    0   N/A  N/A     15624    C+G   ...rive\app-3.19.0\QuarkCloudDrive.exe      N/A      |
# |    0   N/A  N/A     16556    C+G   ...on\wallpaper_engine\wallpaper64.exe      N/A      |
# |    0   N/A  N/A     17040      C   ...tWare\Anaconda3\envs\sup\python.exe      N/A      |
# |    0   N/A  N/A     19116    C+G   ...CBS_cw5n1h2txyewy\TextInputHost.exe      N/A      |
# |    0   N/A  N/A     20628    C+G   ...ekyb3d8bbwe\PhoneExperienceHost.exe      N/A      |
# |    0   N/A  N/A     21372    C+G   ...0784\office6\promecefpluginhost.exe      N/A      |
# |    0   N/A  N/A     23852    C+G   ...ft Office\root\Office16\WINWORD.EXE      N/A      |
# |    0   N/A  N/A     23960      C   ...tWare\Anaconda3\envs\sup\python.exe      N/A      |
# +-----------------------------------------------------------------------------------------+
